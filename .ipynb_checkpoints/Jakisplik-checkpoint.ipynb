# %%
print ("Hello")
# Out:
# Hello

# %%
x = "Hello"
x = x + " World"
print (x)
# Out:
# Hello World

# %%
print ("hi")
car=15
print ("there is", car, "cars")
table = {"R1":966,"C1":1917}
print (table['R1'])
# Out:
# hi
# there is 15 cars
# 966

# %%
table["R2"]= 17

# %%
print(table)
# Out:
# {'R1': 966, 'C1': 1917, 'R2': 17}

# %%
for klucz in table:
    print (klucz)
# Out:
# R1
# C1
# R2

# %%
for klucz, wartosc in table.iteritems():
 	print (klucz)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-9f4af3785560> in <module>()
# ----> 1 for klucz, wartosc in table.iteritems():
#       2         print (klucz)
#
# AttributeError: 'dict' object has no attribute 'iteritems'
